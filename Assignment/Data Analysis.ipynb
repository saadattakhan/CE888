# %% [markdown]
# ### Import Necessary Libraries and Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline
import collections
import numpy as np


from wordcloud import WordCloud

import matplotlib.cm as cm
from matplotlib import rcParams

from utils import Utils
from mltools import ML
from data import Data

# %% [markdown]
# ### WordCloud Display - 20 Most Frequent Words

# %%
def display(words):
    wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(words)



    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()


    counted_words = collections.Counter(words.split(" "))

    words = []
    counts = []
    for letter, count in counted_words.most_common(20):
        words.append(letter)
        counts.append(count)

    colors = cm.rainbow(np.linspace(0, 1, 20))
    rcParams['figure.figsize'] = 20, 10

    plt.title('Top words in the tweets vs their count')
    plt.xlabel('Count')
    plt.ylabel('Words')
    plt.barh(words, counts, color=colors)
    plt.show()

# %% [markdown]
# ### Load Hate Speech Dataset

# %%
data=Data("hate/","hate")
X_train,y_train,X_val,y_val,X_test,y_test=data.preprocess()
# Out:
# Preprocessing dataset...
# Dataset preprocessing completed successfully
# Extracting features from data...
# Using spacy vectors

# %% [markdown]
# ### Analyse Not-Hate Tweets

# %%
print("Analysis for Not-Hate")
words=data.get_words(0)
display(words)
# Out:
# Analysis for Not-Hate

# %% [markdown]
# ### Analyze Hate Tweets

# %%
print("Analysis for Hate")
words=data.get_words(1)
display(words)
# Out:
# Analysis for Hate

# %% [markdown]
# ### Train Machine Learning Model and Evaluate Performance

# %%
ml=ML(data._best_model)
ml.fit_evaluate(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# Validation F-1 Score
# f1: 0.6701871768344629
#
# Testing F-1 Score
# f1: 0.5661182976957218

# %% [markdown]
# ### Load Offensive Speech Dataset

# %%
data=Data("offensive/","offensive")
X_train,y_train,X_val,y_val,X_test,y_test=data.preprocess()
# Out:
# Preprocessing dataset...
# Dataset preprocessing completed successfully
# Extracting features from data...
# Using TF-IDF vectors

# %% [markdown]
# ### Analyse Not-Offensive Tweets

# %%
print("Analysis for Not-Offensive")
words=data.get_words(0)
display(words)
# Out:
# Analysis for Not-Offensive

# %% [markdown]
# ### Analyse Offensive Tweets

# %%
print("Analysis for Offensive")
words=data.get_words(1)
display(words)
# Out:
# Analysis for Offensive

# %% [markdown]
# ### Train Machine Learning Model and Evaluate Performance

# %%
from mltools import ML
ml=ML(data._best_model)
ml.fit_evaluate(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# Validation F-1 Score
# f1: 0.6861990867606065
#
# Testing F-1 Score
# f1: 0.715108426980608

# %% [markdown]
# ### Load Sentiment Analysis Dataset

# %%
data=Data("sentiment/","sentiment")
X_train,y_train,X_val,y_val,X_test,y_test=data.preprocess()
# Out:
# Preprocessing dataset...
# Dataset preprocessing completed successfully
# Extracting features from data...
# Using spacy vectors

# %% [markdown]
# ### Analyse Negative Tweets

# %%
print("Analysis for Negative")
words=data.get_words(0)
display(words)
# Out:
# Analysis for Negative

# %% [markdown]
# ### Analyse Neutral Tweets

# %%
print("Analysis for Neutral")
words=data.get_words(1)
display(words)
# Out:
# Analysis for Neutral

# %% [markdown]
# ### Analyse Positive Tweets

# %%
print("Analysis for Positive")
words=data.get_words(2)
display(words)
# Out:
# Analysis for Positive

# %% [markdown]
# ### Train Machine Learning Model and Evaluate Performance

# %%
from mltools import ML
ml=ML(data._best_model)
ml.fit_evaluate(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# C:\Users\Myra\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Validation F-1 Score
# f1: 0.5733446369171634
#
# Testing F-1 Score
# f1: 0.5516275377823288
